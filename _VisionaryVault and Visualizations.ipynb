# %%
import pandas as pd

# %%
mydata=pd.read_csv(r'C:\Users\IT-Department\Desktop\insurance.csv')

# %%
mydata
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
print(mydata)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Handle missing values
mydata.dropna()  # or use df.fillna() as appropriate
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=mydata[['sex','age','bmi','children','charges']]

# %%
x
# Out:
#       sex  age     bmi  children      charges
# 0       0   19  27.900         0  16884.92400
# 1       1   18  33.770         1   1725.55230
# 2       1   28  33.000         3   4449.46200
# 3       1   33  22.705         0  21984.47061
# 4       1   32  28.880         0   3866.85520
# ...   ...  ...     ...       ...          ...
# 1333    1   50  30.970         3  10600.54830
# 1334    0   18  31.920         0   2205.98080
# 1335    0   18  36.850         0   1629.83350
# 1336    0   21  25.800         0   2007.94500
# 1337    0   61  29.070         0  29141.36030
#
# [1338 rows x 5 columns]

# %%
print(x,mydata)
# Out:
#       sex  age     bmi  children      charges
# 0       0   19  27.900         0  16884.92400
# 1       1   18  33.770         1   1725.55230
# 2       1   28  33.000         3   4449.46200
# 3       1   33  22.705         0  21984.47061
# 4       1   32  28.880         0   3866.85520
# ...   ...  ...     ...       ...          ...
# 1333    1   50  30.970         3  10600.54830
# 1334    0   18  31.920         0   2205.98080
# 1335    0   18  36.850         0   1629.83350
# 1336    0   21  25.800         0   2007.94500
# 1337    0   61  29.070         0  29141.36030
#
# [1338 rows x 5 columns]       age  sex     bmi  children  smoker  region      charges  LabelEncoder()  \
# 0      19    0  27.900         0       1       3  16884.92400               0
# 1      18    1  33.770         1       0       2   1725.55230               1
# 2      28    1  33.000         3       0       2   4449.46200               1
# ...

# %%
y=mydata[['smoker','region']]

# %%
y
# Out:
#       smoker  region
# 0          1       3
# 1          0       2
# 2          0       2
# 3          0       1
# 4          0       1
# ...      ...     ...
# 1333       0       1
# 1334       0       0
# 1335       0       2
# 1336       0       3
# 1337       1       1
#
# [1338 rows x 2 columns]

# %%
print(y,mydata)
# Out:
#       smoker  region
# 0          1       3
# 1          0       2
# 2          0       2
# 3          0       1
# 4          0       1
# ...      ...     ...
# 1333       0       1
# 1334       0       0
# 1335       0       2
# 1336       0       3
# 1337       1       1
#
# [1338 rows x 2 columns]       age  sex     bmi  children  smoker  region      charges  LabelEncoder()  \
# 0      19    0  27.900         0       1       3  16884.92400               0
# 1      18    1  33.770         1       0       2   1725.55230               1
# 2      28    1  33.000         3       0       2   4449.46200               1
# 3      33    1  22.705         0       0       1  21984.47061               1
# 4      32    1  28.880         0       0       1   3866.85520               1
# ...   ...  ...     ...       ...     ...     ...          ...             ...
# 1333   50    1  30.970         3       0       1  10600.54830               1
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
sex=LabelEncoder()
smoker=LabelEncoder()
region=LabelEncoder()

# %%
mydata['sex']=sex.fit_transform(mydata[['sex']])
mydata['smoker']=smoker.fit_transform(mydata[['smoker']])
mydata['region']=region.fit_transform(mydata[['region']])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(mydata)
# Out:
#       age  sex     bmi  children  smoker  region      charges  LabelEncoder()  \
# 0      19    0  27.900         0       1       3  16884.92400               0
# 1      18    1  33.770         1       0       2   1725.55230               1
# 2      28    1  33.000         3       0       2   4449.46200               1
# 3      33    1  22.705         0       0       1  21984.47061               1
# 4      32    1  28.880         0       0       1   3866.85520               1
# ...   ...  ...     ...       ...     ...     ...          ...             ...
# 1333   50    1  30.970         3       0       1  10600.54830               1
# 1334   18    0  31.920         0       0       0   2205.98080               0
# 1335   18    0  36.850         0       0       2   1629.83350               0
# 1336   21    0  25.800         0       0       3   2007.94500               0
# 1337   61    0  29.070         0       1       1  29141.36030               0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
 scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
def train_model(x_train, y_train):
    model = LinearRegression()
    model.fit(x_train, y_train)
    return model

# %%
print(model)
# Out:
# LinearRegression()

# %%
print(x_train)
# Out:
#       sex  age     bmi  children      charges
# 915     0   24  33.990         0   2473.33410
# 424     1   48  30.200         2   8968.33000
# 788     1   29  22.515         3   5209.57885
# 1092    1   23  32.700         3   3591.48000
# 264     0   53  38.060         3  20462.99766
# ...   ...  ...     ...       ...          ...
# 718     0   51  36.670         2  10848.13430
# 639     1   56  33.660         4  12949.15540
# 1253    0   40  29.300         4  15828.82173
# 223     1   19  34.800         0  34779.61500
# 836     1   36  31.500         0   4402.23300
#
# [1070 rows x 5 columns]

# %%
print(x_test)
# Out:
#       sex  age     bmi  children      charges
# 838     0   35  23.465         2   6402.29135
# 755     1   31  27.645         2   5031.26955
# 176     1   38  27.835         2   6455.86265
# 2       1   28  33.000         3   4449.46200
# 710     1   18  35.200         1   1727.54000
# ...   ...  ...     ...       ...          ...
# 359     0   18  20.790         0   1607.51010
# 498     0   44  23.980         2   8211.10020
# 959     1   48  36.670         1  28468.91901
# 1324    1   31  25.935         1   4239.89265
# 89      0   55  26.980         0  11082.57720
#
# [268 rows x 5 columns]

# %%
print(y_test)
# Out:
#       smoker  region
# 838        0       0
# 755        0       0
# 176        0       1
# 2          0       2
# 710        0       2
# ...      ...     ...
# 359        0       2
# 498        0       2
# 959        0       1
# 1324       0       1
# 89         0       1
#
# [268 rows x 2 columns]

# %%
print(y_train)
# Out:
#       smoker  region
# 915        0       2
# 424        0       3
# 788        0       0
# 1092       0       3
# 264        0       2
# ...      ...     ...
# 718        0       1
# 639        0       2
# 1253       0       3
# 223        1       3
# 836        0       3
#
# [1070 rows x 2 columns]

# %%
def evaluate_model(model, x_test, y_test):
    predictions = model.predict(x_test)
    mse = mean_squared_error(y_test, predictions)
    return mse

# %%
print(mse)
# Out:
# 0.6361516585296147

# %%
print(evaluate_model)
# Out:
# <function evaluate_model at 0x0000021AD67B3B00>

# %%
print(predictions)
# Out:
# [[ 9.86155829e-02  1.31752066e+00]
#  [ 5.43009189e-02  1.42857855e+00]
#  [ 3.86421558e-02  1.43007341e+00]
#  [-1.85625329e-03  1.63656417e+00]
#  [-9.98010109e-03  1.68956674e+00]
#  [ 3.28671263e-01  1.44323736e+00]
#  [ 4.65755956e-01  1.41890292e+00]
#  [ 1.01178859e-01  1.39408791e+00]
#  [ 1.00693868e+00  1.47316588e+00]
#  [ 9.82783078e-01  1.43749176e+00]
#  [ 4.66317476e-01  1.19684513e+00]
#  [-2.13545267e-02  1.71767569e+00]
#  [ 8.33905009e-02  1.35877792e+00]
#  [ 7.09081806e-02  1.38109657e+00]
#  [ 1.49631764e-02  1.71835757e+00]
#  [ 9.74240857e-02  1.25881909e+00]
#  [ 1.68655179e-01  1.04820570e+00]
#  [ 2.41453877e-01  1.37292608e+00]
#  [ 7.47609496e-02  1.41740920e+00]
#  [ 6.90557554e-03  1.52668959e+00]
#  [-1.24985942e-02  1.63733469e+00]
#  [ 6.33679760e-03  1.63232548e+00]
#  [-3.54308938e-02  1.73914482e+00]
#  [ 1.02490534e-01  1.37141888e+00]
#  [ 4.47112546e-01  1.45889841e+00]
#  [-4.79448277e-02  1.63880624e+00]
#  [-5.16740222e-02  1.59955032e+00]
# ...

# %%
print(y_test, predictions)
# Out:
#       smoker  region
# 838        0       0
# 755        0       0
# 176        0       1
# 2          0       2
# 710        0       2
# ...      ...     ...
# 359        0       2
# 498        0       2
# 959        0       1
# 1324       0       1
# 89         0       1
#
# [268 rows x 2 columns] [[ 9.86155829e-02  1.31752066e+00]
#  [ 5.43009189e-02  1.42857855e+00]
#  [ 3.86421558e-02  1.43007341e+00]
#  [-1.85625329e-03  1.63656417e+00]
#  [-9.98010109e-03  1.68956674e+00]
#  [ 3.28671263e-01  1.44323736e+00]
#  [ 4.65755956e-01  1.41890292e+00]
#  [ 1.01178859e-01  1.39408791e+00]
#  [ 1.00693868e+00  1.47316588e+00]
#  [ 9.82783078e-01  1.43749176e+00]
#  [ 4.66317476e-01  1.19684513e+00]
#  [-2.13545267e-02  1.71767569e+00]
#  [ 8.33905009e-02  1.35877792e+00]
#  [ 7.09081806e-02  1.38109657e+00]
#  [ 1.49631764e-02  1.71835757e+00]
#  [ 9.74240857e-02  1.25881909e+00]
#  [ 1.68655179e-01  1.04820570e+00]
#  [ 2.41453877e-01  1.37292608e+00]
# ...

# %%
print(model.predict)
# Out:
# <bound method LinearModel.predict of LinearRegression()>

# %%
if __name__ == "__main__":
    mydata = load_data(r'C:\Users\IT-Department\Desktop\insurance.csv')
    processed_data = preprocess_data(mydata)

    model = train_model(x_train_scaled, y_train)
    mse = evaluate_model(model,x_test_scaled, y_test)

    print(f'Model Mean Squared Error: {mse:.2f}')
# Out:
# <function load_data at 0x0000021AD1675080>
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
# Model Mean Squared Error: 0.64

# %%
print(processed_data)
# Out:
# None

# %%
print(mse)
# Out:
# 0.6361516585296149

# %%
print(x_test_scaled)
# Out:
# [[-1.00187091 -0.31103275 -1.19045284  0.74674315 -0.58478252]
#  [ 0.99813258 -0.59403024 -0.50383056  0.74674315 -0.69753591]
#  [ 0.99813258 -0.09878464 -0.47262045  0.74674315 -0.58037679]
#  ...
#  [ 0.99813258  0.60870908  0.97864938 -0.08211076  1.22998589]
#  [ 0.99813258 -0.59403024 -0.78472149 -0.08211076 -0.76261907]
#  [-1.00187091  1.10395469 -0.61306592 -0.91096467 -0.19987391]]

# %%
print(x_train_scaled)
# Out:
# [[-1.00187091 -1.08927584  0.53842265 -0.91096467 -0.90790156]
#  [ 0.99813258  0.60870908 -0.08413679  0.74674315 -0.37375046]
#  [ 0.99813258 -0.73552898 -1.34650336  1.57559706 -0.68287168]
#  ...
#  [-1.00187091  0.04271411 -0.23197413  2.40445097  0.19045916]
#  [ 0.99813258 -1.4430227   0.67147625 -0.91096467  1.74898009]
#  [ 0.99813258 -0.24028338  0.12940603 -0.91096467 -0.74926813]]

# %%
print(train_model)
# Out:
# <function train_model at 0x0000021AD6857E20>

# %%
print(evaluate_model)
# Out:
# <function evaluate_model at 0x0000021AD67B3B00>

# %%
print(model)
# Out:
# LinearRegression()

# %%
print(x_test,y_test)
# Out:
#       sex  age     bmi  children      charges
# 838     0   35  23.465         2   6402.29135
# 755     1   31  27.645         2   5031.26955
# 176     1   38  27.835         2   6455.86265
# 2       1   28  33.000         3   4449.46200
# 710     1   18  35.200         1   1727.54000
# ...   ...  ...     ...       ...          ...
# 359     0   18  20.790         0   1607.51010
# 498     0   44  23.980         2   8211.10020
# 959     1   48  36.670         1  28468.91901
# 1324    1   31  25.935         1   4239.89265
# 89      0   55  26.980         0  11082.57720
#
# [268 rows x 5 columns]       smoker  region
# 838        0       0
# 755        0       0
# 176        0       1
# 2          0       2
# 710        0       2
# ...      ...     ...
# 359        0       2
# 498        0       2
# 959        0       1
# 1324       0       1
# 89         0       1
#
# [268 rows x 2 columns]

# %%
model.score(x_test,y_test)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -144339539.60575345

# %%
print(model_file_path)
# Out:
# model.pkl

# %% [markdown]
# # Visualization in paroject

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Histogram of a numerical feature (e.g., 'age')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(mydata['age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 2. Box plot for another numerical feature (e.g., 'charges')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='sex', y='charges', data=mydata)
plt.title('Charges by Sex')
plt.xlabel('Sex')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# # 3. Scatter plot for two numerical features (e.g., 'age' vs 'charges')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='charges', data=mydata, hue='smoker', style='sex')
plt.title('Charges vs. Age')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# # 4. Bar plot for a categorical feature (e.g., 'region')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='region', data=mydata)
plt.title('Count of Insurance Customers by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 9. Pie Chart of Gender Distribution

# %%
gender_counts = mydata['sex'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 10. Strip Plot of Charges by Age Group

# %%
mydata['age_group'] = pd.cut(mydata['age'], bins=[18, 30, 40, 50, 60, 70, 80], labels=['18-30', '31-40', '41-50', '51-60', '61-70', '71-80'])
plt.figure(figsize=(10, 6))
sns.stripplot(x='age_group', y='charges', data=mydata, jitter=True)
plt.title('Charges by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# # 11. Count Plot of Smoker Status by Gender

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='sex', hue='smoker', data=mydata)
plt.title('Smoker Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 12. Box Plot of BMI by Smoker Status

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='smoker', y='bmi', data=mydata)
plt.title('BMI by Smoker Status')
plt.xlabel('Smoker')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# # 13. Line Plot of Average Charges by Age

# %%
avg_charges_age = mydata.groupby('age')['charges'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x='age', y='charges', data=avg_charges_age)
plt.title('Average Charges by Age')
plt.xlabel('Age')
plt.ylabel('Average Charges')
plt.show()

# %% [markdown]
# # 14. Bar Plot of Charges by Number of Children

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='children', y='charges', data=mydata, ci=None)
plt.title('Charges by Number of Children')
plt.xlabel('Number of Children')
plt.ylabel('Charges')
plt.show()
# Out:
# C:\Users\IT-Department\AppData\Local\Temp\ipykernel_8160\1129440462.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='children', y='charges', data=mydata, ci=None)

# %% [markdown]
# # 15. Count Plot of Regions by Smoker Status

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='region', hue='smoker', data=mydata)
plt.title('Smoker Status by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 16. Bar Plot of Charges by Region

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='region', y='charges', data=mydata, ci=None)
plt.title('Total Charges by Region')
plt.xlabel('Region')
plt.ylabel('Total Charges')
plt.show()
# Out:
# C:\Users\IT-Department\AppData\Local\Temp\ipykernel_8160\3923678196.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='region', y='charges', data=mydata, ci=None)

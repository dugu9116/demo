# %%
import pandas as pd

# %%
mydata=pd.read_csv(r'C:\Users\IT-Department\Desktop\netflix1.csv')

# %%
mydata
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
# Display the first few rows of the dataset
print(mydata.head())
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# # Data Exploration
# Description: Explore the dataset to understand its structure, types of data, and any missing values.

# %%
# Check the structure of the dataset
print(mydata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB
# None

# %%
# Summary statistics
print(mydata.describe())
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Check for missing values
print(mydata.isnull().sum())
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# # . Data Cleaning
# Description: Clean the data as necessary, such as handling missing values and formatting columns.

# %%
# Example: Filling missing values or dropping columns with too many missing values
mydata.fillna(method='ffill', inplace=True)  # Forward fill for missing values

# %%
print(mydata.fillna)
# Out:
# <bound method DataFrame.fillna of      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
# ...

# %%
# Example: Convert date columns to datetime
mydata['release_year'] = pd.to_datetime(mydata['release_year'])

# %%
print(mydata['release_year'] )
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       1993
#         ...
# 8785    2016
# 8786    2016
# 8787    2012
# 8788    2016
# 8789    2016
# Name: release_year, Length: 8790, dtype: int64

# %% [markdown]
# # Data Visualization
# Libraries: We'll use libraries like Matplotlib and Seaborn for creating visualizations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# %% [markdown]
# # A. Content Distribution by Type
# Visualizing the distribution of content (Movies vs. TV Shows).

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=mydata, x='type', palette='Set2')
plt.title('Content Distribution: Movies vs. TV Shows')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Rating Distribution (Histogram)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(mydata['rating'], bins=10, kde=True, color='purple')
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Content by Country (Bar Chart)

# %%
country_counts = mydata['country'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=country_counts.values, y=country_counts.index, palette='Greens_d')
plt.title('Top 10 Countries with Most Titles')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# # Release Trend Over Time (Line Plot)

# %%
release_trend = mydata['release_year'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x=release_trend.index, y=release_trend.values)
plt.title('Trend of Releases Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.show()

# %% [markdown]
# # Pie Chart of Content Types

# %%
plt.figure(figsize=(8, 8))
mydata['type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title('Content Types Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Ratings vs. Duration (Scatter Plot)

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='duration', y='rating', data=mydata)
plt.title('Ratings vs. Duration')
plt.xlabel('Duration (minutes)')
plt.ylabel('Rating')
plt.show()

# %%
import pandas as pd

# %%
mydata=pd.read_csv(r'C:\Users\IT-Department\Desktop\retail_sales_dataset.csv')

# %%
mydata
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
print(mydata.head())
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
print(mydata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
# None

# %%
print(mydata.describe())
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
print(mydata.isnull().sum())
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Plot sales over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=mydata, x='Date', y='Gender')  # Replace 'date' and 'sales' with actual column names
plt.title('Sales Trends Over Time')
plt.xticks(rotation=45)
plt.show()

# %%
x=mydata[['Transaction ID','Age','Quantity','Price per Unit','Total Amount']]

# %%
x
# Out:
#      Transaction ID  Age  Quantity  Price per Unit  Total Amount
# 0                 1   34         3              50           150
# 1                 2   26         2             500          1000
# 2                 3   50         1              30            30
# 3                 4   37         1             500           500
# 4                 5   30         2              50           100
# ..              ...  ...       ...             ...           ...
# 995             996   62         1              50            50
# 996             997   52         3              30            90
# 997             998   23         4              25           100
# 998             999   36         3              50           150
# 999            1000   47         4              30           120
#
# [1000 rows x 5 columns]

# %%
print(x,mydata)
# Out:
#      Transaction ID  Age  Quantity  Price per Unit  Total Amount
# 0                 1   34         3              50           150
# 1                 2   26         2             500          1000
# 2                 3   50         1              30            30
# 3                 4   37         1             500           500
# 4                 5   30         2              50           100
# ..              ...  ...       ...             ...           ...
# 995             996   62         1              50            50
# 996             997   52         3              30            90
# 997             998   23         4              25           100
# 998             999   36         3              50           150
# 999            1000   47         4              30           120
#
# [1000 rows x 5 columns]      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# ...

# %%
y=mydata[['Date','Product Category','Customer ID']]

# %%
y
# Out:
#      Date  Product Category  Customer ID
# 0     307                 0            0
# 1      54                 1            1
# 2      11                 2            2
# 3     132                 1            3
# 4     117                 0            4
# ..    ...               ...          ...
# 995   127                 1          996
# 996   300                 0          997
# 997   282                 0          998
# 998   318                 2          999
# 999    94                 2          100
#
# [1000 rows x 3 columns]

# %%
print(y,mydata)
# Out:
#      Date  Product Category  Customer ID
# 0     307                 0            0
# 1      54                 1            1
# 2      11                 2            2
# 3     132                 1            3
# 4     117                 0            4
# ..    ...               ...          ...
# 995   127                 1          996
# 996   300                 0          997
# 997   282                 0          998
# 998   318                 2          999
# 999    94                 2          100
#
# [1000 rows x 3 columns]      Transaction ID  Date  Customer ID  Gender  Age  Product Category  \
# 0                 1   307            0       1   34                 0
# 1                 2    54            1       0   26                 1
# 2                 3    11            2       1   50                 2
# 3                 4   132            3       1   37                 1
# 4                 5   117            4       1   30                 0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Gender=LabelEncoder()
label_encoder = LabelEncoder()
label_encoder = LabelEncoder()
label_encoder = LabelEncoder()
mydata['Product Category'] = label_encoder.fit_transform(mydata['Product Category'])
mydata['Date'] = label_encoder.fit_transform(mydata['Date'])
mydata['Customer ID'] = label_encoder.fit_transform(mydata['Customer ID'])

# %%
print(mydata)
# Out:
#      Transaction ID  Date  Customer ID  Gender  Age  Product Category  \
# 0                 1   307            0       1   34                 0
# 1                 2    54            1       0   26                 1
# 2                 3    11            2       1   50                 2
# 3                 4   132            3       1   37                 1
# 4                 5   117            4       1   30                 0
# ..              ...   ...          ...     ...  ...               ...
# 995             996   127          996       1   62                 1
# 996             997   300          997       1   52                 0
# 997             998   282          998       0   23                 0
# 998             999   318          999       0   36                 2
# 999            1000    94          100       1   47                 2
#
#      Quantity  Price per Unit  Total Amount
# 0           3              50           150
# ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# [[2.5206e+02 1.1200e+00 5.2869e+02]
#  [1.4019e+02 7.6000e-01 7.3701e+02]
#  [1.4659e+02 9.2000e-01 7.4152e+02]
#  [1.8318e+02 9.5000e-01 6.6203e+02]
#  [8.2800e+01 1.1300e+00 4.1666e+02]
#  [2.3981e+02 7.9000e-01 6.7639e+02]
#  [2.1589e+02 1.7400e+00 6.2749e+02]
#  [1.8607e+02 8.4000e-01 5.1953e+02]
#  [1.7267e+02 1.3000e+00 8.5965e+02]
#  [1.2474e+02 1.4200e+00 1.3716e+02]
#  [1.3980e+02 9.7000e-01 8.1486e+02]
#  [1.6931e+02 1.4900e+00 7.5170e+01]
#  [2.0831e+02 1.5100e+00 6.3540e+02]
#  [2.2295e+02 9.1000e-01 9.7533e+02]
#  [1.8080e+02 4.9000e-01 9.3660e+02]
#  [1.6800e+02 1.3200e+00 9.0283e+02]
#  [7.3450e+01 8.3000e-01 2.8052e+02]
#  [2.0039e+02 1.7500e+00 8.8782e+02]
#  [1.8172e+02 1.0400e+00 7.6279e+02]
#  [1.2526e+02 8.8000e-01 3.2454e+02]
#  [1.9399e+02 1.7000e+00 5.5037e+02]
#  [2.0564e+02 8.9000e-01 1.7183e+02]
#  [2.6611e+02 1.3700e+00 3.7369e+02]
#  [2.5589e+02 8.9000e-01 5.2664e+02]
#  [1.6364e+02 7.9000e-01 2.1404e+02]
#  [1.3392e+02 7.0000e-01 2.3289e+02]
# ...

# %%
print(x_test)
# Out:
# [[ 0.0815028   0.30683669  0.44059449  1.69655572  1.85360305]
#  [ 0.82805378 -0.06041249 -0.44502257 -0.6751438  -0.62746706]
#  [ 0.83842254  0.45373636 -1.33063963  0.64246705 -0.27302847]
#  [ 0.56192218  0.15993702  1.32621154 -0.80690488 -0.62746706]
#  [-0.2986852  -1.67630886  1.32621154  1.69655572  2.73969952]
#  [ 0.62413476 -1.7497587   0.44059449 -0.78055266 -0.64518899]
#  [ 0.44440953  1.11478487 -1.33063963 -0.6751438  -0.71607671]
#  [ 0.05385277 -1.7497587  -1.33063963  0.64246705 -0.27302847]
#  [ 1.24971683  1.55548388  1.32621154 -0.6751438  -0.45024777]
#  [-1.24915519  0.30683669 -0.44502257  1.69655572  0.96750658]
#  [ 1.08381661 -1.67630886  0.44059449 -0.80690488 -0.67177188]
#  [-1.45653046  0.38028652 -0.44502257 -0.6751438  -0.62746706]
#  [ 0.47897207  0.08648718 -0.44502257  0.64246705  0.25862941]
#  [ 1.64372985  0.38028652 -1.33063963 -0.78055266 -0.75152057]
#  [ 1.52276094  0.30683669 -1.33063963  0.64246705 -0.27302847]
# ...

# %%
print(model.predict)
# Out:
# <bound method ForestRegressor.predict of RandomForestRegressor(random_state=42)>

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model.predict(x_test)

print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 3870.0659696666676
# R^2 Score: 0.21923702391002897

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')  # Line for perfect prediction
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicted Sales')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.legend()
plt.grid()
plt.show()

# %%
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, color='purple')
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Predicted Sales')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Sales')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.ecdfplot(errors, color='blue')
plt.title('Cumulative Distribution Function of Errors')
plt.xlabel('Error')
plt.ylabel('CDF')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=[y_test, y_pred], palette='muted')
plt.xticks([0, 1], ['Actual Sales', 'Predicted Sales'])
plt.title('Violin Plot of Actual vs. Predicted Sales')
plt.ylabel('Sales')
plt.grid()
plt.show()
